# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import re

# 1. 爬取所有型號的網址
def scrape_sogi_links(url):
    base_url = "https://www.sogi.com.tw"
    response = requests.get(url)
    response.encoding = 'utf-8'

    if response.status_code != 200:
        print(f"無法取得網頁: {url}，狀態碼: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    mixitup_div = soup.find('div', id="mixitup-block_38-cellphone")

    if not mixitup_div:
        print(f"找不到目標區塊: {url}")
        return []

    links = []
    for card in mixitup_div.find_all('div', class_="card shadow text-center p-2"):
        a_tag = card.find('a', class_="font-weight-bold text-danger text-decoration-none")
        if a_tag and 'href' in a_tag.attrs:
            full_url = base_url + a_tag['href']
            links.append(full_url)

    return links

# 2. 爬取單個型號的所有店家資訊
def scrape_sogi_data(url):
    response = requests.get(url)
    response.encoding = 'utf-8'

    if response.status_code != 200:
        print(f"無法取得 {url}，狀態碼: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    items = soup.find_all('div', class_='col-12 col-md-6 col-lg-3 my-2')

    results = []
    model_name = url.split("/")[-2].split("-")[0]  # 提取型號名稱
    storage_size = url.split("/")[-2].split("-")[-1] #手機容量
    brand = url.split("/")[-2].split("_")[0]  # 品牌
  
 
      


    for item in items:
        # 提取顏色
        color = item.find('span', class_='badge badge-light rounded-0 mx-0')
        color = color.text.strip() if color else 'N/A'

        # 提取店名
        shop_name = item.find('a', class_='text-row-2 mb-2 w-75 w-lg-100')
        shop_name = shop_name.text.strip() if shop_name else 'N/A'

        # 提取評分
        rating = item.find('a', class_='text-dark text-decoration-none text-row-1')
        rating_value = rating.find('small').text.strip().split("\n")[0] if rating else 'N/A'  # Extract rating (before \n)
        #提取評價數
        review_count = re.search(r"\((\d+)\)", rating.text)  # Extract review count inside parentheses
        review_count = review_count.group(1) if review_count else 'N/A'

        #價格
        price = item.find('span', class_='h4 text-danger font-weight-bold')
        price = price.text.strip().replace('$', '') if price else 'N/A'

        # 提取地址
        address = item.find('div', class_='text-muted text-decoration-none')
        address = address.find('small').text.strip() if address else 'N/A'

        # 提取更新時間
        update_time = item.find('div', class_='font-small text-muted mb-4')
        update_time = update_time.text.strip() if update_time else 'N/A'

        if update_time != 'N/A':
           date = update_time.split('：')[-1]
        else:
           date = 'N/A'

        # 提取機況資訊
        condition = item.find('div', class_='text-row-3 font-small mb-2')
        condition = condition.decode_contents().strip().replace('<br>', '\n') if condition else 'N/A'

        if condition != 'N/A':
        # Use regex to extract the required values
         appearance = re.search(r"外觀機況：([^<]+)", condition)
         warranty = re.search(r"門市保固：([^<]+)", condition)
         battery_health = re.search(r"電池健康度：([^%]+)", condition)

        # Extract values or assign 'N/A' if not found
         appearance_value = appearance.group(1) if appearance else 'N/A'
         warranty_value = warranty.group(1) if warranty else 'N/A'
         battery_health_value = battery_health.group(1) if battery_health else 'N/A'

        
        # 儲存資料
        results.append({
            '品牌': brand,
            '機型': model_name,
            '金額': price,
            '容量': storage_size,
            '顏色': color,
            '店名': shop_name,
            '評分': rating_value,
            '評價數': review_count,
            '地址': address,
            '更新時間': date,
            '外觀完整': appearance_value,
            '門市保固': warranty_value,
            '電池健康度': battery_health_value
        })

    return results

# 3. 爬取所有品牌的所有型號的店家資訊，並存入 JSON 檔案
def scrape_all_brands(brand_urls, output_json):
    all_results = []

    for brand_url in brand_urls:
        print(f"\n====== 開始爬取品牌: {brand_url} ======")
        model_links = scrape_sogi_links(brand_url)

        for index, model_url in enumerate(model_links, start=1):
            print(f"正在爬取第 {index}/{len(model_links)} 個型號: {model_url}")
            model_data = scrape_sogi_data(model_url)
            all_results.extend(model_data)
            time.sleep(1)  # 避免過快請求被封鎖

    # 存入 JSON 檔案
    with open(output_json, mode='w', encoding='utf-8') as file:
        json.dump(all_results, file, ensure_ascii=False, indent=4)

    print(f"\n共爬取 {len(all_results)} 筆資料，已成功存成 {output_json}")

# 4. 執行爬蟲
brand_urls = [
    "https://www.sogi.com.tw/brands/SAMSUNG/22",
    "https://www.sogi.com.tw/brands/Apple/116",
    "https://www.sogi.com.tw/brands/vivo/5603",
    "https://www.sogi.com.tw/brands/OPPO/5372",
    "https://www.sogi.com.tw/brands/ASUS/49",
    "https://www.sogi.com.tw/brands/Xiaomi/5368",
    "https://www.sogi.com.tw/brands/Sony/26",
    "https://www.sogi.com.tw/brands/realme/6012",
    "https://www.sogi.com.tw/brands/POCO/6016",
    "https://www.sogi.com.tw/brands/Google/4041",
    "https://www.sogi.com.tw/brands/HTC/154",
    "https://www.sogi.com.tw/brands/Motorola/15",
    "https://www.sogi.com.tw/brands/SHARP/39",
    "https://www.sogi.com.tw/brands/Nokia/17"
]

output_json = "sogi_data.json"
scrape_all_brands(brand_urls, output_json)
# Out:
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/SAMSUNG/22 ======
# 正在爬取第 1/56 個型號: https://www.sogi.com.tw/usedprices/samsung-galaxy-s25-256gb/907
# 正在爬取第 2/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_fold6-256gb/817
# 正在爬取第 3/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip6-256gb/815
# 正在爬取第 4/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a55_5g-256gb/772
# 正在爬取第 5/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a55_5g-128gb/771
# 正在爬取第 6/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a35_5g-128gb/770
# 正在爬取第 7/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s24_ultra-512gb/753
# 正在爬取第 8/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a15_5g-128gb/743
# 正在爬取第 9/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a25_5g-128gb/744
# 正在爬取第 10/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s24-256gb/745
# 正在爬取第 11/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s24plus-256gb/746
# 正在爬取第 12/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s24_ultra-256gb/747
# 正在爬取第 13/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s24-512gb/755
# 正在爬取第 14/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23_fe-256gb/710
# 正在爬取第 15/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_m34_5g-128gb/699
# 正在爬取第 16/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_fold5-512gb/676
# 正在爬取第 17/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip5-512gb/674
# 正在爬取第 18/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip5-256gb/665
# 正在爬取第 19/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_fold5-256gb/664
# 正在爬取第 20/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a54_5g-256gb/620
# 正在爬取第 21/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a54_5g-128gb/619
# 正在爬取第 22/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a34_5g-128gb/623
# 正在爬取第 23/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23_ultra-512gb/607
# 正在爬取第 24/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23-256gb/605
# 正在爬取第 25/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23_ultra-256gb/604
# 正在爬取第 26/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23plus-256gb/603
# 正在爬取第 27/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s23-128gb/602
# 正在爬取第 28/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a14_5g-128gb/598
# 正在爬取第 29/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a14_5g-64gb/597
# 正在爬取第 30/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a13_5g-64gb/556
# 正在爬取第 31/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a23_5g-128gb/558
# 正在爬取第 32/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_fold4-512gb/553
# 正在爬取第 33/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip4-256gb/549
# 正在爬取第 34/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip4-128gb/544
# 正在爬取第 35/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_fold4-256gb/543
# 正在爬取第 36/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_m53_5g-128gb/500
# 正在爬取第 37/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a53_5g-256gb/496
# 正在爬取第 38/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a33_5g-128gb/495
# 正在爬取第 39/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a53_5g-128gb/494
# 正在爬取第 40/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_m33_5g-128gb/492
# 正在爬取第 41/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22-128gb/469
# 正在爬取第 42/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22plus-128gb/470
# 正在爬取第 43/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22_ultra-256gb/471
# 正在爬取第 44/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22-256gb/477
# 正在爬取第 45/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22_ultra-512gb/478
# 正在爬取第 46/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s22plus-256gb/479
# 正在爬取第 47/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_s21_fe_5g-256gb/458
# 正在爬取第 48/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_z_flip3_5g-128gb/404
# 正在爬取第 49/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a52s_5g-128gb/417
# 正在爬取第 50/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a52s_5g-256gb/421
# 正在爬取第 51/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a22_5g-128gb/394
# 正在爬取第 52/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a22_5g-64gb/389
# 正在爬取第 53/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a52_5g-256gb/345
# 正在爬取第 54/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a52_5g-128gb/344
# 正在爬取第 55/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a32_5g-64gb/338
# 正在爬取第 56/56 個型號: https://www.sogi.com.tw/usedprices/samsung_galaxy_a32_5g-128gb/337
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Apple/116 ======
# 正在爬取第 1/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16-128gb/305
# 正在爬取第 2/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_plus-128gb/306
# 正在爬取第 3/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro-128gb/307
# 正在爬取第 4/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro_max-256gb/308
# 正在爬取第 5/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16-256gb/309
# 正在爬取第 6/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_plus-256gb/311
# 正在爬取第 7/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro-256gb/313
# 正在爬取第 8/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro-512gb/314
# 正在爬取第 9/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro-1tb/315
# 正在爬取第 10/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro_max-512gb/316
# 正在爬取第 11/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_16_pro_max-1tb/317
# 正在爬取第 12/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15-128gb/244
# 正在爬取第 13/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_plus-128gb/245
# 正在爬取第 14/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro-128gb/246
# 正在爬取第 15/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro_max-256gb/247
# 正在爬取第 16/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15-256gb/248
# 正在爬取第 17/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_plus-256gb/250
# 正在爬取第 18/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro-256gb/252
# 正在爬取第 19/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro-512gb/253
# 正在爬取第 20/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro-1tb/254
# 正在爬取第 21/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro_max-512gb/255
# 正在爬取第 22/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_15_pro_max-1tb/256
# 正在爬取第 23/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_plus-128gb/215
# 正在爬取第 24/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_plus-256gb/216
# 正在爬取第 25/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14-128gb/193
# 正在爬取第 26/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro-128gb/194
# 正在爬取第 27/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro_max-128gb/195
# 正在爬取第 28/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14-256gb/201
# 正在爬取第 29/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14-512gb/202
# 正在爬取第 30/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro-256gb/203
# 正在爬取第 31/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro-512gb/204
# 正在爬取第 32/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro-1tb/205
# 正在爬取第 33/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro_max-256gb/206
# 正在爬取第 34/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro_max-512gb/207
# 正在爬取第 35/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_14_pro_max-1tb/208
# 正在爬取第 36/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_se_2022-64gb/186
# 正在爬取第 37/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_se_2022-128gb/187
# 正在爬取第 38/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13-128gb/158
# 正在爬取第 39/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_mini-128gb/159
# 正在爬取第 40/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro-128gb/160
# 正在爬取第 41/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro_max-128gb/161
# 正在爬取第 42/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_mini-256gb/162
# 正在爬取第 43/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13-256gb/164
# 正在爬取第 44/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13-512gb/165
# 正在爬取第 45/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro-256gb/166
# 正在爬取第 46/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro-512gb/167
# 正在爬取第 47/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro-1tb/168
# 正在爬取第 48/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro_max-256gb/169
# 正在爬取第 49/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro_max-512gb/170
# 正在爬取第 50/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_13_pro_max-1tb/171
# 正在爬取第 51/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_mini-64gb/130
# 正在爬取第 52/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_mini-128gb/131
# 正在爬取第 53/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_mini-256gb/132
# 正在爬取第 54/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro_max-128gb/133
# 正在爬取第 55/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro_max-256gb/134
# 正在爬取第 56/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro_max-512gb/135
# 正在爬取第 57/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12-64gb/116
# 正在爬取第 58/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12-128gb/117
# 正在爬取第 59/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12-256gb/118
# 正在爬取第 60/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro-128gb/119
# 正在爬取第 61/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro-256gb/120
# 正在爬取第 62/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_12_pro-512gb/121
# 正在爬取第 63/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_se_2020-64gb/89
# 正在爬取第 64/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_se_2020-128gb/90
# 正在爬取第 65/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_se_2020-256gb/91
# 正在爬取第 66/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11-256gb/73
# 正在爬取第 67/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro-512gb/74
# 正在爬取第 68/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro_max-512gb/75
# 正在爬取第 69/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro-256gb/76
# 正在爬取第 70/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro-64gb/77
# 正在爬取第 71/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro_max-256gb/78
# 正在爬取第 72/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11_pro_max-64gb/79
# 正在爬取第 73/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11-128gb/80
# 正在爬取第 74/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_11-64gb/81
# 正在爬取第 75/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8-64gb/82
# 正在爬取第 76/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xr-256gb/44
# 正在爬取第 77/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xr-64gb/45
# 正在爬取第 78/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xr-128gb/46
# 正在爬取第 79/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xs-64gb/38
# 正在爬取第 80/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xs_max-64gb/39
# 正在爬取第 81/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xs-256gb/40
# 正在爬取第 82/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xs_max-256gb/41
# 正在爬取第 83/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_xs_max-512gb/43
# 正在爬取第 84/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8_plus_product_red_special_edition-64gb/30
# 正在爬取第 85/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8_plus_product_red_special_edition-256gb/31
# 正在爬取第 86/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_x-64gb/28
# 正在爬取第 87/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_x-256gb/29
# 正在爬取第 88/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8-64gb/24
# 正在爬取第 89/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8_plus-64gb/25
# 正在爬取第 90/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8-256gb/26
# 正在爬取第 91/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_8_plus-256gb/27
# 正在爬取第 92/92 個型號: https://www.sogi.com.tw/usedprices/apple_iphone_7_product_red_special_edition-256gb/7
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/vivo/5603 ======
# 正在爬取第 1/34 個型號: https://www.sogi.com.tw/usedprices/vivo-x200-256gb/872
# 正在爬取第 2/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v40_lite-256gb/849
# 正在爬取第 3/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v40-256gb/830
# 正在爬取第 4/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y28s_5g-256gb/813
# 正在爬取第 5/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v30e-256gb/788
# 正在爬取第 6/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y38_5g-256gb/787
# 正在爬取第 7/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y100_5g-256gb/782
# 正在爬取第 8/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v30_5g-512gb/774
# 正在爬取第 9/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v30_5g-256gb/763
# 正在爬取第 10/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v30_pro_5g-512gb/767
# 正在爬取第 11/34 個型號: https://www.sogi.com.tw/usedprices/vivo-x100-pro-512gb/733
# 正在爬取第 12/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x100-256gb/732
# 正在爬取第 13/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v29_5g-512gb/700
# 正在爬取第 14/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v29_5g-256gb/692
# 正在爬取第 15/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v27_5g-256gb/625
# 正在爬取第 16/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v27_5g-256gb/624
# 正在爬取第 17/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y55s_5g-128gb/596
# 正在爬取第 18/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y55s_5g-128gb/595
# 正在爬取第 19/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x90_pro-256gb/594
# 正在爬取第 20/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x90-256gb/593
# 正在爬取第 21/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v21s-128gb/587
# 正在爬取第 22/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v25_5g-128gb/572
# 正在爬取第 23/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y02s-32gb/536
# 正在爬取第 24/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x80-256gb/510
# 正在爬取第 25/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v23e_5g-128gb/452
# 正在爬取第 26/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y76_5g-128gb/448
# 正在爬取第 27/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y21s-128gb/434
# 正在爬取第 28/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x70_pro_5g-256gb/431
# 正在爬取第 29/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x70_5g-128gb/430
# 正在爬取第 30/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y52_5g-128gb/384
# 正在爬取第 31/34 個型號: https://www.sogi.com.tw/usedprices/vivo_v21_5g-128gb/363
# 正在爬取第 32/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x60-128gb/348
# 正在爬取第 33/34 個型號: https://www.sogi.com.tw/usedprices/vivo_y72_5g-128gb/354
# 正在爬取第 34/34 個型號: https://www.sogi.com.tw/usedprices/vivo_x60_pro-256gb/349
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/OPPO/5372 ======
# 正在爬取第 1/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a3x-128gb/839
# 正在爬取第 2/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a3_pro_5g-256gb/824
# 正在爬取第 3/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a3_pro_5g-128gb/823
# 正在爬取第 4/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno12_f_5g-256gb/814
# 正在爬取第 5/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno12_f_5g-256gb/812
# 正在爬取第 6/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno12_5g-512gb/805
# 正在爬取第 7/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno12_5g-256gb/800
# 正在爬取第 8/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno11_5g-256gb/750
# 正在爬取第 9/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno11_5g-256gb/739
# 正在爬取第 10/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno11_pro_5g-512gb/740
# 正在爬取第 11/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a79_5g-256gb/729
# 正在爬取第 12/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a79_5g-128gb/728
# 正在爬取第 13/33 個型號: https://www.sogi.com.tw/usedprices/oppo_find_n3-512gb/722
# 正在爬取第 14/33 個型號: https://www.sogi.com.tw/usedprices/oppo_find_n3_flip-256gb/703
# 正在爬取第 15/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno10_pro-256gb/657
# 正在爬取第 16/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno10_proplus-256gb/652
# 正在爬取第 17/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a78_5g-128gb/621
# 正在爬取第 18/33 個型號: https://www.sogi.com.tw/usedprices/oppo_find_n2_flip-256gb/600
# 正在爬取第 19/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno8_5g-256gb/591
# 正在爬取第 20/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno8_z_5g-128gb/541
# 正在爬取第 21/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a57_2022-64gb/525
# 正在爬取第 22/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno8_pro_5g-256gb/524
# 正在爬取第 23/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno8_5g-256gb/523
# 正在爬取第 24/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a77_5g-64gb/516
# 正在爬取第 25/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno7_z_5g-128gb/498
# 正在爬取第 26/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno7_pro_5g-256gb/464
# 正在爬取第 27/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno7_5G-256gb/463
# 正在爬取第 28/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a55-64gb/435
# 正在爬取第 29/33 個型號: https://www.sogi.com.tw/usedprices/oppp_reno6_z_5g-128gb/401
# 正在爬取第 30/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno6_pro_5g-256gb/397
# 正在爬取第 31/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno6_5g-128gb/396
# 正在爬取第 32/33 個型號: https://www.sogi.com.tw/usedprices/oppo_reno5_z_5g-128gb/356
# 正在爬取第 33/33 個型號: https://www.sogi.com.tw/usedprices/oppo_a74_5g-128gb/357
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/ASUS/49 ======
# 正在爬取第 1/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_11_ultra-256gb/775
# 正在爬取第 2/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_8_pro_edition-1tb/752
# 正在爬取第 3/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_8-512gb/749
# 正在爬取第 4/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_8_pro-512gb/748
# 正在爬取第 5/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_10-128gb/659
# 正在爬取第 6/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_10-256gb/655
# 正在爬取第 7/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_7-512gb/634
# 正在爬取第 8/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_6_batman-256gb/574
# 正在爬取第 9/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_6d_ultimate-512gb/568
# 正在爬取第 10/21 個型號: https://www.sogi.com.tw/usedprices/asus-rog-phone-6d-256gb/567
# 正在爬取第 11/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_9-256gb/533
# 正在爬取第 12/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_9-128gb/532
# 正在爬取第 13/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_6_pro-512gb/530
# 正在爬取第 14/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_6-512gb/529
# 正在爬取第 15/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_5s-256gb/459
# 正在爬取第 16/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_5s-256gb/414
# 正在爬取第 17/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_8_flip_zs672ks-256gb/371
# 正在爬取第 18/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_8_zs590ks-256gb/369
# 正在爬取第 19/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_8_zs590ks-256gb/368
# 正在爬取第 20/21 個型號: https://www.sogi.com.tw/usedprices/asus_zenfone_8_zs590ks-256gb/366
# 正在爬取第 21/21 個型號: https://www.sogi.com.tw/usedprices/asus_rog_phone_5-256gb/343
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Xiaomi/5368 ======
# 正在爬取第 1/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_14_pro_plus_5g-256gb/901
# 正在爬取第 2/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_14t-512gb/846
# 正在爬取第 3/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_14_ultra-512gb/766
# 正在爬取第 4/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_14-512gb/762
# 正在爬取第 5/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_13_pro_plus_5g-512gb/758
# 正在爬取第 6/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_13c-128gb/734
# 正在爬取第 7/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_12_5g-128gb/697
# 正在爬取第 8/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_12_5g-256gb/694
# 正在爬取第 9/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_13t_pro-512gb/701
# 正在爬取第 10/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_13_ultra-512gb/642
# 正在爬取第 11/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_12c-64gb/628
# 正在爬取第 12/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_13-256gb/615
# 正在爬取第 13/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_12_5g-128gb/612
# 正在爬取第 14/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_12t_pro-256gb/583
# 正在爬取第 15/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_10_5g-128gb/562
# 正在爬取第 16/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_10_2022-64gb/537
# 正在爬取第 17/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_12_lite-256gb/535
# 正在爬取第 18/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_11s_5g-128gb/513
# 正在爬取第 19/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_10a-64gb/503
# 正在爬取第 20/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_10c-64gb/502
# 正在爬取第 21/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_11_pro_5g-128gb/493
# 正在爬取第 22/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_12x-256gb/488
# 正在爬取第 23/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11t-256gb/440
# 正在爬取第 24/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11t_pro-256gb/439
# 正在爬取第 25/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11_lite_5g_ne-128gb/432
# 正在爬取第 26/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_10-64gb/418
# 正在爬取第 27/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11_lite_5g-128gb/372
# 正在爬取第 28/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11_lite_5g-128gb/361
# 正在爬取第 29/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_10_pro-128gb/360
# 正在爬取第 30/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_11-256gb/347
# 正在爬取第 31/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_xiaomi_10t_lite_5g-128gb/342
# 正在爬取第 32/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_note_9t_5g-128gb/340
# 正在爬取第 33/33 個型號: https://www.sogi.com.tw/usedprices/xiaomi_redmi_9t-64gb/336
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Sony/26 ======
# 正在爬取第 1/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_1_vi-256gb/791
# 正在爬取第 2/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_10_vi-128gb/792
# 正在爬取第 3/10 個型號: https://www.sogi.com.tw/usedprices/sony-xperia-5-v-256gb/698
# 正在爬取第 4/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_10_v-128gb/643
# 正在爬取第 5/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_5_iv-256gb/564
# 正在爬取第 6/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_10_iv-128gb/511
# 正在爬取第 7/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_1_iv-256gb/506
# 正在爬取第 8/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_1_iv-512gb/507
# 正在爬取第 9/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_5_iii-256gb/399
# 正在爬取第 10/10 個型號: https://www.sogi.com.tw/usedprices/sony_xperia_1_iii-256gb/392
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/realme/6012 ======
# 正在爬取第 1/16 個型號: https://www.sogi.com.tw/usedprices/realme_gt_7_pro-512gb/880
# 正在爬取第 2/16 個型號: https://www.sogi.com.tw/usedprices/realme_13_5g-256gb/855
# 正在爬取第 3/16 個型號: https://www.sogi.com.tw/usedprices/realme_11x_5g-128gb/689
# 正在爬取第 4/16 個型號: https://www.sogi.com.tw/usedprices/realme_11_pro-256gb/644
# 正在爬取第 5/16 個型號: https://www.sogi.com.tw/usedprices/realme_10t_5g-128gb/631
# 正在爬取第 6/16 個型號: https://www.sogi.com.tw/usedprices/realme_c33-64gb/586
# 正在爬取第 7/16 個型號: https://www.sogi.com.tw/usedprices/realme_c35-64gb/501
# 正在爬取第 8/16 個型號: https://www.sogi.com.tw/usedprices/realme_9_pro_plus-256gb/481
# 正在爬取第 9/16 個型號: https://www.sogi.com.tw/usedprices/realme_c11_2021-64gb/449
# 正在爬取第 10/16 個型號: https://www.sogi.com.tw/usedprices/realme_9i-128gb/450
# 正在爬取第 11/16 個型號: https://www.sogi.com.tw/usedprices/realme_narzo_50a-128gb/442
# 正在爬取第 12/16 個型號: https://www.sogi.com.tw/usedprices/realme_gt_master_edition-256gb/422
# 正在爬取第 13/16 個型號: https://www.sogi.com.tw/usedprices/realme_8_5g-128gb/378
# 正在爬取第 14/16 個型號: https://www.sogi.com.tw/usedprices/realme_8_5g-128gb/385
# 正在爬取第 15/16 個型號: https://www.sogi.com.tw/usedprices/realme_gt-128gb/373
# 正在爬取第 16/16 個型號: https://www.sogi.com.tw/usedprices/realme_c21-64gb/355
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/POCO/6016 ======
# 正在爬取第 1/2 個型號: https://www.sogi.com.tw/usedprices/poco_f6-512gb/796
# 正在爬取第 2/2 個型號: https://www.sogi.com.tw/usedprices/poco_f6_pro-512gb/799
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Google/4041 ======
# 正在爬取第 1/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_9-128gb/831
# 正在爬取第 2/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_9_pro_xl-256gb/832
# 正在爬取第 3/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_8_pro-128gb/716
# 正在爬取第 4/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_8-128gb/717
# 正在爬取第 5/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_8_pro-256gb/719
# 正在爬取第 6/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_8-256gb/720
# 正在爬取第 7/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_7a-128gb/637
# 正在爬取第 8/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_7-128gb/576
# 正在爬取第 9/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_7_Pro-128gb/577
# 正在爬取第 10/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_7_Pro-256gb/580
# 正在爬取第 11/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_6a-128gb/521
# 正在爬取第 12/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_6-128gb/426
# 正在爬取第 13/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_6_pro-128gb/427
# 正在爬取第 14/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_6-256gb/437
# 正在爬取第 15/15 個型號: https://www.sogi.com.tw/usedprices/google_pixel_6_pro-256gb/438
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/HTC/154 ======
# 正在爬取第 1/3 個型號: https://www.sogi.com.tw/usedprices/htc_u23_pro-256gb/640
# 正在爬取第 2/3 個型號: https://www.sogi.com.tw/usedprices/htc_u23_pro-256gb/641
# 正在爬取第 3/3 個型號: https://www.sogi.com.tw/usedprices/htc_desire_22_pro-128gb/527
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Motorola/15 ======
# 正在爬取第 1/3 個型號: https://www.sogi.com.tw/usedprices/motorola_razr_50_ultra-512gb/809
# 正在爬取第 2/3 個型號: https://www.sogi.com.tw/usedprices/motorola_razr_50-256gb/810
# 正在爬取第 3/3 個型號: https://www.sogi.com.tw/usedprices/motorola_razr_40_ultra-512gb/647
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/SHARP/39 ======
# 正在爬取第 1/1 個型號: https://www.sogi.com.tw/usedprices/sharp_aquos_sense7_plus-128gb/663
#
# ====== 開始爬取品牌: https://www.sogi.com.tw/brands/Nokia/17 ======
# 找不到目標區塊: https://www.sogi.com.tw/brands/Nokia/17
#
# 共爬取 3477 筆資料，已成功存成 sogi_data.json
